# %%
x=45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
x=2.25
print(x)
print(type(x))
# Out:
# 2.25
# <class 'float'>

# %%
x="komal"
print(x)
# Out:
# komal

# %%
from os import remove


fruits=["apple","banana","kiwi","coconut","walnut","guava"]
print(fruits)
fruits.extend(["grapes","orange"])
print(fruits)
fruits.append("strawberry")
print(fruits)
fruits.remove("banana")
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'guava']
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'guava', 'grapes', 'orange']
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'guava', 'grapes', 'orange', 'strawberry']
# ['apple', 'kiwi', 'coconut', 'walnut', 'guava', 'grapes', 'orange', 'strawberry']
