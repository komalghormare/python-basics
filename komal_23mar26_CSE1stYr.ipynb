# %%
x=45
print(x)
print(type(x))
# Out:
# 45
# <class 'int'>

# %%
x=2.25
print(x)
print(type(x))
# Out:
# 2.25
# <class 'float'>

# %%
x="komal"
print(x)
print(type(x))
# Out:
# komal
# <class 'str'>

# %%
fruits=["apple","banana","kiwi","coconut","walnut","guava"]
print(fruits)
fruits.remove("banana")
print(fruits)
fruits.append("grapes")
fruits.append("strawberry")
fruits.append("orange")
print(fruits)
fruits.remove("kiwi")
print(fruits)
fruits.extend(["mango","papaya"])
print(fruits)
fruits.remove("coconut")
print(fruits)
# Out:
# ['apple', 'banana', 'kiwi', 'coconut', 'walnut', 'guava']
# ['apple', 'kiwi', 'coconut', 'walnut', 'guava']
# ['apple', 'kiwi', 'coconut', 'walnut', 'guava', 'grapes', 'strawberry', 'orange']
# ['apple', 'coconut', 'walnut', 'guava', 'grapes', 'strawberry', 'orange']
# ['apple', 'coconut', 'walnut', 'guava', 'grapes', 'strawberry', 'orange', 'mango', 'papaya']
# ['apple', 'walnut', 'guava', 'grapes', 'strawberry', 'orange', 'mango', 'papaya']
