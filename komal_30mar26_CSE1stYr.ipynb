# %%
tup_1=('a','b','c')
t_lst = list(tup_1)
print(t_lst)
t_lst.append('d')
print(t_lst)
# Out:
# ['a', 'b', 'c']
# ['a', 'b', 'c', 'd']

# %%
dict_1 = {1: 'A', 2: 'B'}
i_d  = list(dict_1.values())
print(i_d)
# Out:
# ['A', 'B']

# %%
n = "250"
print(type(n))
n = int(n)
print(type(n))
# Out:
# <class 'str'>
# <class 'int'>

# %%
fl = "45.67"
print(type(fl))
f2 = int(float(fl))
print(type(f2))
f2
print(len(fl))
# Out:
# <class 'str'>
# <class 'int'>
# 5

# %%
list_5 = [x for x in range(1,10,2)]
list_5
# Out:
# [1, 3, 5, 7, 9]

# %%
list_1 = [1, 2, 3, 4, 5]
print(list_1[0])
print(list_1[-1])
print(len(list_1))
# Out:
# 1
# 5
# 5

# %%
s= "machine learning"
print(s[0:7])
print(s[11:16])
# Out:
# machine
# rning

# %%
my_list = [1, 2, 3, 4]
my_list[1] = 5
print(my_list)
# Out:
# [1, 5, 3, 4]

# %%
a = "python"
nums = [5,10,15,20]
nums.append(25)
